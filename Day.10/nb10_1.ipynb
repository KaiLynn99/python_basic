# %%
import my_math

print(my_math.add(1,2))

# print(add(1,2))
# Out:
# 3

# %%
from my_math import add as ad
print(ad(2,4))
# Out:
# 6

# %%
# greet 패키지
# greet / ko.py - ko_greet() , en.py - en_greet() 

from greet import ko as k
from greet import en as e

# ko.ko_greet("홍길동")
e.en_greet("test")
# Out:
# 'Hello, test!'
