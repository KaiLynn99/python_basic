# %%
fruits = ["apple", "banana", "orange"]

for fruit in fruits:
    print(fruit)
print("hello")
# Out:
# apple
# banana
# orange
# hello

# %%
nums = {10, 20, 30}

for num in nums:
    print(num)
# Out:
# 10
# 20
# 30

# %%
student = {
    "name": "홍길동",
    "age": 20
}
# 키
for key in student:
    print(key)
# 값
for value in student.values():
    print(value)

# 키 + 값 ->언패킹
for key, value in student.items():
    print(key, value)
# Out:
# name
# age
# 홍길동
# 20
# name 홍길동
# age 20
